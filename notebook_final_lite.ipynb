# %% [markdown]
# # Data Visualization

# %%
# %pip install -q seaborn

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load data:

# %%
d = pd.read_csv("iris.csv")
d.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ss = d.describe() # summary statistics
ss
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Exercise 1: plot using pandas

# %%
d.plot(x = 'sepal_length', y = 'sepal_width', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# your code here
ss.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercise 2: plot using matplotlib

# %%
x = d.iloc[:,0]
y = d.iloc[:,1]
fig = plt.scatter(x, y)

# %%
# create new figure with one subplot
fig, ax = plt.subplots(1)
ax.scatter(x, y)

# %%
# create category color mapping by species
unique_species = d['species'].unique()
d['color'] = d['species'].apply(lambda x: np.where(unique_species == x)[0][0])
# define markers for each category
markers = ['*', 's', 'o']
d['marker'] = d['species'].apply(lambda x: markers[np.where(unique_species == x)[0][0]])

# %%
x1 = d.iloc[:,0]
y1 = d.iloc[:,1]
x2 = d.iloc[:,2]
y2 = d.iloc[:,3]
#
fig, axs = plt.subplots(1,2,
    figsize = (12,5), 
    sharex = 'all', sharey = 'all' # share axis
    )

# a
ax = axs[0]
ax.set_title('1)', loc = 'left')
ax.scatter(x1, y1, 
    c = d['color'], 
    marker = 'x',
    )
ax.set_xlabel(d.columns[0])
ax.set_ylabel(d.columns[1])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# b
ax = axs[1]
ax.set_title('2)', loc = 'left')
ax.scatter(x2, y2, 
    c = d['color'], 
    marker = 'x',
    )
ax.set_xlabel(d.columns[2])
ax.set_ylabel(d.columns[3])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %% [markdown]
# ## Exercise 3: plot using seaborn

# %%
# your code here

g = sns.PairGrid(d, hue="species")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %% [markdown]
# ## Exercise 4: plot another seaborn sample dataset
#
# list of datasets [here](https://github.com/mwaskom/seaborn-data])

# %% [markdown]
# # your code here
